# %% [markdown]
# ![image.png](attachment:de23dea7-195d-45af-b09d-f4580af76ee7.png)

# %% [markdown]
# ![image.png](attachment:96f6da63-5ace-4a7a-85de-a18ad583e37e.png)

# %% [markdown]
# ![image.png](attachment:c6b66277-a75a-401f-8106-3f8e2714fd4b.png)

# %% [markdown]
# ![image.png](attachment:a868017e-e388-40ac-9e3b-44ad04d44686.png)
